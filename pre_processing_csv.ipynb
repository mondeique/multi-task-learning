# %% [markdown]
# ## import library

# %%
import pandas as pd

# %% [markdown]
# ## category csv handling

# %%
df = pd.read_csv('./data/shape_labeling.csv')

# %%
df
# Out:
#                                             cropped_url  shape_source
# 0     https://monde-data.s3.amazonaws.com/cropped-ba...             2
# 1     https://monde-data.s3.amazonaws.com/cropped-ba...             7
# 2     https://monde-data.s3.amazonaws.com/cropped-ba...             2
# 3     https://monde-data.s3.amazonaws.com/cropped-ba...             2
# 4     https://monde-data.s3.amazonaws.com/cropped-ba...             2
# ...                                                 ...           ...
# 1518  https://monde-data.s3.amazonaws.com/cropped-ba...             3
# 1519  https://monde-data.s3.amazonaws.com/cropped-ba...             3
# 1520  https://monde-data.s3.amazonaws.com/cropped-ba...             2
# 1521  https://monde-data.s3.amazonaws.com/cropped-ba...             3
# 1522  https://monde-data.s3.amazonaws.com/cropped-ba...             3
#
# [1523 rows x 2 columns]

# %%
## 중복 제거

df = df.drop_duplicates(['cropped_url'])

# %%
df
# Out:
#                                             cropped_url  shape_source
# 0     https://monde-data.s3.amazonaws.com/cropped-ba...             2
# 1     https://monde-data.s3.amazonaws.com/cropped-ba...             7
# 2     https://monde-data.s3.amazonaws.com/cropped-ba...             2
# 3     https://monde-data.s3.amazonaws.com/cropped-ba...             2
# 4     https://monde-data.s3.amazonaws.com/cropped-ba...             2
# ...                                                 ...           ...
# 1518  https://monde-data.s3.amazonaws.com/cropped-ba...             3
# 1519  https://monde-data.s3.amazonaws.com/cropped-ba...             3
# 1520  https://monde-data.s3.amazonaws.com/cropped-ba...             2
# 1521  https://monde-data.s3.amazonaws.com/cropped-ba...             3
# 1522  https://monde-data.s3.amazonaws.com/cropped-ba...             3
#
# [1523 rows x 2 columns]

# %%
## index 내림차순으로 정리

df = df.reset_index(drop=True)

# %%
df
# Out:
#                                             cropped_url  shape_source
# 0     https://monde-data.s3.amazonaws.com/cropped-ba...             2
# 1     https://monde-data.s3.amazonaws.com/cropped-ba...             7
# 2     https://monde-data.s3.amazonaws.com/cropped-ba...             2
# 3     https://monde-data.s3.amazonaws.com/cropped-ba...             2
# 4     https://monde-data.s3.amazonaws.com/cropped-ba...             2
# ...                                                 ...           ...
# 1518  https://monde-data.s3.amazonaws.com/cropped-ba...             3
# 1519  https://monde-data.s3.amazonaws.com/cropped-ba...             3
# 1520  https://monde-data.s3.amazonaws.com/cropped-ba...             2
# 1521  https://monde-data.s3.amazonaws.com/cropped-ba...             3
# 1522  https://monde-data.s3.amazonaws.com/cropped-ba...             3
#
# [1523 rows x 2 columns]

# %% [markdown]
# ## post-processing for making training csv

# %%
for i in range(len(df)):
    df['cropped_url'][i] = './data/cropped-bag-images-dev/' + df['cropped_url'][i].split('/')[-1]
# Out:
# /usr/local/var/pyenv/versions/3.7.4/envs/mondeique-data/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df
# Out:
#                                           cropped_url  shape_source
# 0     ./data/cropped-bag-images-dev/R0CY20H72DT_2.jpg             2
# 1     ./data/cropped-bag-images-dev/VYDQU6L3R9O_2.jpg             7
# 2     ./data/cropped-bag-images-dev/IQJU1KR1Z2E_2.jpg             2
# 3     ./data/cropped-bag-images-dev/8T3QNQUN4MI_1.jpg             2
# 4     ./data/cropped-bag-images-dev/PSLFSUDEMUZ_2.jpg             2
# ...                                               ...           ...
# 1518  ./data/cropped-bag-images-dev/BTQT593JUUV_1.jpg             3
# 1519  ./data/cropped-bag-images-dev/6G6W06GKV2J_1.jpg             3
# 1520  ./data/cropped-bag-images-dev/TVJN1EYDRGI_1.jpg             2
# 1521  ./data/cropped-bag-images-dev/FWE73MIK53C_1.jpg             3
# 1522  ./data/cropped-bag-images-dev/5A0TBBNWEIB_1.jpg             3
#
# [1523 rows x 2 columns]

# %%
df.columns = ['filename', 'shape_source']

# %%
df
# Out:
#                                              filename  shape_source
# 0     ./data/cropped-bag-images-dev/R0CY20H72DT_2.jpg             2
# 1     ./data/cropped-bag-images-dev/VYDQU6L3R9O_2.jpg             7
# 2     ./data/cropped-bag-images-dev/IQJU1KR1Z2E_2.jpg             2
# 3     ./data/cropped-bag-images-dev/8T3QNQUN4MI_1.jpg             2
# 4     ./data/cropped-bag-images-dev/PSLFSUDEMUZ_2.jpg             2
# ...                                               ...           ...
# 1518  ./data/cropped-bag-images-dev/BTQT593JUUV_1.jpg             3
# 1519  ./data/cropped-bag-images-dev/6G6W06GKV2J_1.jpg             3
# 1520  ./data/cropped-bag-images-dev/TVJN1EYDRGI_1.jpg             2
# 1521  ./data/cropped-bag-images-dev/FWE73MIK53C_1.jpg             3
# 1522  ./data/cropped-bag-images-dev/5A0TBBNWEIB_1.jpg             3
#
# [1523 rows x 2 columns]

# %% [markdown]
# ## Merge augmented data & origin one

# %%
origin_df = df
aug_df = pd.read_csv('./data/aug_shape_labeling.csv')

# %%
final_df = pd.concat([origin_df, aug_df])
final_df = final_df.reset_index(drop=True)
# Out:
# /usr/local/var/pyenv/versions/3.7.4/envs/mondeique-data/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
final_df = final_df.drop(['Unnamed: 0'], axis=1)

# %%
final_df
# Out:
#                                                filename  shape_source
# 0       ./data/cropped-bag-images-dev/R0CY20H72DT_2.jpg             2
# 1       ./data/cropped-bag-images-dev/VYDQU6L3R9O_2.jpg             7
# 2       ./data/cropped-bag-images-dev/IQJU1KR1Z2E_2.jpg             2
# 3       ./data/cropped-bag-images-dev/8T3QNQUN4MI_1.jpg             2
# 4       ./data/cropped-bag-images-dev/PSLFSUDEMUZ_2.jpg             2
# ...                                                 ...           ...
# 1751  ./data/cropped-bag-images-dev/aug_data/half_ci...             6
# 1752  ./data/cropped-bag-images-dev/aug_data/half_ci...             6
# 1753  ./data/cropped-bag-images-dev/aug_data/half_ci...             6
# 1754  ./data/cropped-bag-images-dev/aug_data/half_ci...             6
# 1755  ./data/cropped-bag-images-dev/aug_data/half_ci...             6
#
# [1756 rows x 2 columns]

# %% [markdown]
# ## split data to training & test

# %%
from sklearn.model_selection import train_test_split
df_train, df_test = train_test_split(final_df, test_size = 0.25)

# %%
## export to csv

df_train.to_csv('./data/training_csv', index=False)
df_test.to_csv('./data/test_csv', index=False)

# %%
train_df = pd.read_csv('./data/training_csv')

# %%
train_df
# Out:
#                                                filename  shape_source
# 0       ./data/cropped-bag-images-dev/5O2BQILGU6S_1.jpg             1
# 1       ./data/cropped-bag-images-dev/X63VMOKHOQY_1.jpg             4
# 2       ./data/cropped-bag-images-dev/TGEWLADRYBR_1.jpg             9
# 3       ./data/cropped-bag-images-dev/SQJAPKTWWFJ_2.jpg             1
# 4       ./data/cropped-bag-images-dev/EKF4LQ1U4FN_1.jpg             1
# ...                                                 ...           ...
# 1312  ./data/cropped-bag-images-dev/aug_data/half_ci...             6
# 1313    ./data/cropped-bag-images-dev/5K7NXOFC1BE_1.jpg             9
# 1314    ./data/cropped-bag-images-dev/4J8QNAF9UJW_1.jpg             7
# 1315    ./data/cropped-bag-images-dev/RYBS5VVBK5E_1.jpg             6
# 1316    ./data/cropped-bag-images-dev/2MEJY0R3JDU_1.jpg             9
#
# [1317 rows x 2 columns]
